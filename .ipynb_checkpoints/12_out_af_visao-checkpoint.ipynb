# %%
# !pip install ultralytics --upgrade -q

# import zipfile

# zip_path = "/content/dataset.zip"
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall('/content/')

# !ls /content

from google.colab import drive
import zipfile

# Monta o Google Drive
drive.mount('/content/drive')

# Caminho do zip no Drive
zip_path = "/content/drive/MyDrive/dataset_final.zip"  # ajuste conforme seu caminho

# Pasta de destino para extrair
extract_path = "/content/"

# Extrair arquivos
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(f"✅ Arquivos extraídos em: {extract_path}")

from ultralytics import YOLO

model = YOLO("yolo11n.pt")

# results = model.train(data="/content/dataset/dataset.yaml", cfg='/content/args.yaml')
results = model.train(data="/content/dataset_final/dataset.yaml", cfg='/content/args.yaml')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.6 MB/s eta 0:00:00
# Mounted at /content/drive
# ✅ Arquivos extraídos em: /content/
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# WARNING ⚠️ 'crop_fraction' is deprecated and will be removed in the future.
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
results.summary()

# %%
val_metrics = model.val(
    data="/content/dataset/dataset.yaml",
    split='test'
)
val_metrics.summary()
